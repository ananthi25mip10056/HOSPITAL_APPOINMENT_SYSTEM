# %%
### Code for Docter appoinment system 
print("Welcome to Docter Appoinment System")
doctor=[" Dr.Sharma - Pediatrician",
        " Dr.prem Kumar - Cardiologist", 
        " Dr.Prasad - Dermatologist",
        " Dr.Amit Shah - Neurologist",
        " Dr.Anmol singh - Oncologist",
        " Dr.Anudeep - General Surgeon",
        " Dr.Gulpreeth - Orthopedic Surgeon",
        " Dr.Ashish - Neuro Surgeon",
        " Dr.Preetha - Psychiatrist",
        " Dr.Koushal - Radiologist"]
doctor1=["1. Dr.Sharma - Pediatrician",
        "2. Dr.prem Kumar - Cardiologist", 
        "3. Dr.Prasad - Dermatologist",
        "4. Dr.Amit Shah - Neurologist",
        "5. Dr.Anmol singh - Oncologist",
        "6. Dr.Anudeep - General Surgeon",
        "7. Dr.Gulpreeth - Orthopedic Surgeon",
        "8. Dr.Ashish - Neuro Surgeon",
        "9. Dr.Preetha - Psychiatrist",
        "10. Dr.Koushal - Radiologist"]

print ("CAUTION : FOR BETTER CONVENIENCE PLEASE CHECK FOR THE AVAILABLE DOCTORS AND THEN CONTINUE FOR BOOKING")
print("1. Show Available Docters ")
print("2. Exit")
a=int(input("Please choose an option from above(1/2):"))


if a==1 :
    print (doctor1)
    print("1. Book Appoinment")
    print("2. View Appoinment")
    print("3. Exit")
    a=int(input("Please choose an option from above(1/2/3):"))
    if a==1:
        print ("Please enter patient details:")
        patientname = str(input("Please enter patient's name:"))
        patientage = int(input("Please enter patient's age:"))
        appoinmenttime1 =str(input("Enter appoinment time(AM/PM):"))
        n= int(input("Please enter the number written before the respective doctor(1-10):"))
        b=doctor[1-n]
        print ("Patient's Name:", patientname)
        print ("Patient's Age:", patientage )
        print ("Appoinment Time:", appoinmenttime1)
        print ("doctor:",b)
        print ("Your appoinment for",b,"is successful")
        print("1. Add appoinment")
        print("2. View Appoinment")
        print("3. Exit")
        a=int(input("Please choose an option from above(1/2/3):"))
        if a==1:
            appoinmenttime2 =str(input("Enter appoinment time(AM/PM):"))
            n= int(input("Please enter the number written before the respective doctor(1-10):"))
            c=doctor[1-n]
            print ("Patient's Name:", patientname)
            print ("Patient's Age:", patientage )
            print ("Appoinment Time:", appoinmenttime2)
            print ("doctor:",c)
            print ("Your appoinment for",c,"is successful")
            print("1. Add appoinment")
            print("2. View Appoinment")
            print("3. Exit")
            a=int(input("Please choose an option from above(1/2/3):"))
            if a==1:
                appoinmenttime3 =str(input("Enter appoinment time(AM/PM):"))
                n= int(input("Please enter the number written before the respective doctor(1-10):"))
                d=doctor[1-n]
                print ("Patient's Name:", patientname)
                print ("Patient's Age:", patientage )
                print ("Appoinment Time:", appoinmenttime3)
                print ("doctor:",d)
                print ("Your appoinment for",d,"is successful")
                print("1. Add appoinment")
                print("2. View Appoinment")
                print("3. Exit")
                a=int(input("Please choose an option from above(1/2/3):"))
                if a==1:
                    appoinmenttime4 =str(input("Enter appoinment time(AM/PM1):"))
                    n= int(input("Please enter the number written before the respective doctor(1-10):"))
                    e=doctor[1-n]
                    print ("Patient's Name:", patientname)
                    print ("Patient's Age:", patientage )
                    print ("Appoinment Time:", appoinmenttime4)
                    print ("doctor:",e)
                    print ("Your appoinment for",e,"is successful")
                    print("1. View Appoinment")
                    print("2. Exit")
                    a=int(input("Please choose an option from above(1/2):"))
                    if a==2:
                       patientname = str(input("Please enter patient's name:"))
                       patientage = int(input("Please enter patient's age:"))
                       print ("Patient's Name:", patientname)
                       print ("Patient's Age:", patientage )
                       print ("Appoinment Time of",b,"is",appoinmenttime1,
                             ", Appoinment Time of",c,"is",appoinmenttime2,
                             ", Appoinment Time of",d,"is",appoinmenttime3,
                              "and Appoinment Time of",e,"is",appoinmenttime4)
                       print ("Doctor:",b,
                             "Doctor:",c,
                             "Doctor:",d,
                             "Doctor:",e)
                       print ("Your appoinment for",b,c,d,"and",e,"is successful")
                       print ("Thank you for visiting our Doctor Appoinment System")
                    
                    else:
                        print("Thank you for visiting our Doctor Appoinment System")
                elif a==2:
                     patientname = str(input("Please enter patient's name:"))
                     patientage = int(input("Please enter patient's age:"))
                     print ("Patient's Name:", patientname)
                     print ("Patient's Age:", patientage )
                     print ("Appoinment Time of",b,"is",appoinmenttime1,
                             ", Appoinment Time of",c,"is",appoinmenttime2,
                             "and Appoinment Time of",d,"is",appoinmenttime3)
                     print ("Doctor:",b,
                             "Doctor:",c,
                             "Doctor:",d)
                     print ("Your appoinment for",b,c,"and",d,"is successful")
                     print ("Thank you for visiting our Doctor Appoinment System")
            
                else:
                    print("Thank you for visiting our Doctor Appoinment System")
            elif a==2:
                patientname = str(input("Please enter patient's name:"))
                patientage = int(input("Please enter patient's age:"))
                print ("Patient's Name:", patientname)
                print ("Patient's Age:", patientage )
                print ("Appoinment Time of",b,"is",appoinmenttime1,
                             "and Appoinment Time of",c,"is",appoinmenttime2)
                print ("Doctor:",b,
                     "Doctor:",c,)
                print ("Your appoinment for",b,"and",c,"is successful") 
                print ("Thank you for visiting our Doctor Appoinment System")  
                
            else:
                print("Thank you for visiting our Doctor Appoinment System")
        elif a==2:
            patientname = str(input("Please enter patient's name:"))
            patientage = int(input("Please enter patient's age:"))
            print ("Patient's Name:", patientname)
            print ("Patient's Age:", patientage )
            print ("Appoinment Time of",b,"is",appoinmenttime1)
            print ("Doctor:",b)
            print ("Your appoinment for",b,"is successful")
            print ("Thank you for visiting our Doctor Appoinment System")
        else:
            print("Thank you for visiting our Doctor Appoinment System")    
    elif a==2:
        patientname = str(input("Please enter patient's name:"))
        patientage = int(input("Please enter patient's age:"))
        print ("There is no appoinment in this name")
    else:
        print("Thank you for visiting our Doctor Appoinment System")

else:
    print("Thank you for visiting our Doctor Appoinment System")
# Out:
# Welcome to Docter Appoinment System
# CAUTION : FOR BETTER CONVENIENCE PLEASE CHECK FOR THE AVAILABLE DOCTORS AND THEN CONTINUE FOR BOOKING
# 1. Show Available Docters
# 2. Exit
# Please choose an option from above(1/2): 1
# ['1. Dr.Sharma - Pediatrician', '2. Dr.prem Kumar - Cardiologist', '3. Dr.Prasad - Dermatologist', '4. Dr.Amit Shah - Neurologist', '5. Dr.Anmol singh - Oncologist', '6. Dr.Anudeep - General Surgeon', '7. Dr.Gulpreeth - Orthopedic Surgeon', '8. Dr.Ashish - Neuro Surgeon', '9. Dr.Preetha - Psychiatrist', '10. Dr.Koushal - Radiologist']
# 1. Book Appoinment
# 2. View Appoinment
# 3. Exit
# Please choose an option from above(1/2/3): 1
# Please enter patient details:
# Please enter patient's name: Ananthi T
# Please enter patient's age: 18
# Enter appoinment time(AM/PM): 7:00 PM
# Please enter the number written before the respective doctor(1-10): 1
# Patient's Name: Ananthi T
# Patient's Age: 18
# Appoinment Time: 7:00 PM
# doctor:  Dr.Sharma - Pediatrician
# ...
